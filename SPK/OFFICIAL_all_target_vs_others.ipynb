# %%
import os
import random
import shutil
from pathlib import Path
import numpy as np
import torch
import torchaudio
import soundfile as sf
from multiprocessing import Pool, cpu_count
import multiprocessing as mp
from silero_vad import load_silero_vad
from IPython.display import Audio
from scipy.fft import rfft, fft

# %%
import numpy as np

def adjust_array_length(arr: np.ndarray, n: int) -> np.ndarray:
    """
    调整输入数组的长度为 n。
    - 若 arr 长度 >= n，则随机抽取 n 个元素（不放回）；
    - 若 arr 长度 < n，则补齐至 n，补充部分来自于 arr 的随机采样（放回）。

    参数:
        arr (np.ndarray): 输入的一维或二维数组（假设按第一个维度为样本维）。
        n (int): 目标长度。

    返回:
        np.ndarray: 调整后的数组，长度为 n。
    """
    arr_len = len(arr)
    if arr_len >= n:
        idx = np.random.choice(arr_len, n, replace=False)
        return arr[idx]
    else:
        deficit = n - arr_len
        idx = np.random.choice(arr_len, deficit, replace=True)
        extra_arr = arr[idx]
        return np.concatenate([arr, extra_arr], axis=0)

# %%
import numpy as np
from collections import Counter

# NOISE
X_NOISE = np.load('OFFICIAL/NOISE/03mfcc/X.npy')
Y_NOISE = np.load('OFFICIAL/NOISE/03mfcc/Y.npy')

# 打印样本数量
print(f'✅ X_NOISE 长度：{len(X_NOISE)}')
print(f'✅ Y_NOISE 长度：{len(Y_NOISE)}')

# 打印形状（假设是 numpy 数组）
print(f'📐 X_NOISE 形状: {X_NOISE.shape}')          # e.g. (13600, 8000)
print(f'📐 Y_NOISE 形状: {Y_NOISE.shape}')          # e.g. (13600,)

# 打印标签各类数量
label_counts = Counter(Y_NOISE)
print('📊 标签类别数量分布:')
for label, count in sorted(label_counts.items()):
    print(f'  类别 {label}: {count} 个样本')
# Out:
# ✅ X_NOISE 长度：7000
# ✅ Y_NOISE 长度：7000
# 📐 X_NOISE 形状: (7000, 8000)
# 📐 Y_NOISE 形状: (7000,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 1000 个样本
#   类别 2: 500 个样本
#   类别 3: 1000 个样本
#   类别 4: 1000 个样本
#   类别 5: 3000 个样本

# %%
import numpy as np
from collections import Counter
from pathlib import Path

categories = ['BOARD', 'IPAD', 'DIY', 'OTHERS', 'PC', 'PHONE']
base_path = Path('OFFICIAL')

# 数据字典：每类一个子字典，包含 X, X_mfcc, Y
data_dict = {}

for cat in categories:
    prefix = cat.upper()
    folder = base_path / prefix / '03mfcc'
    try:
        # 加载数据
        X = np.load(folder / 'X.npy')
        X_mfcc = np.load(folder / 'X_mfcc.npy')
        Y = np.load(folder / 'Y.npy')

        # 存入字典
        data_dict[prefix] = {
            'X': X,
            'X_mfcc': X_mfcc,
            'Y': Y
        }

        # 打印信息
        print(f'\n📁 加载类别：{prefix}')
        print(f'✅ X 长度：{len(X)}')
        print(f'✅ Y 长度：{len(Y)}')
        print(f'✅ X_mfcc 长度：{len(X_mfcc)}')
        print(f'📐 X 形状: {X.shape}')
        print(f'📐 X_mfcc 形状: {X_mfcc.shape}')
        print(f'📐 Y 形状: {Y.shape}')

        # 标签统计
        label_counts = Counter(Y)
        print('📊 标签类别数量分布:')
        for label, count in sorted(label_counts.items()):
            print(f'  类别 {label}: {count} 个样本')

    except FileNotFoundError as e:
        print(f'❌ 类别 {prefix} 加载失败: {e}')
# Out:
# 📁 加载类别：BOARD
# ✅ X 长度：14500
# ✅ Y 长度：14500
# ✅ X_mfcc 长度：14500
# 📐 X 形状: (14500, 8000)
# 📐 X_mfcc 形状: (14500, 31, 13)
# 📐 Y 形状: (14500,)
# 📊 标签类别数量分布:
#   类别 0: 2900 个样本
#   类别 1: 2900 个样本
#   类别 2: 2900 个样本
#   类别 3: 2900 个样本
#   类别 4: 2900 个样本
#
# 📁 加载类别：IPAD
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：DIY
# ✅ X 长度：9000
# ✅ Y 长度：9000
# ✅ X_mfcc 长度：9000
# 📐 X 形状: (9000, 8000)
# 📐 X_mfcc 形状: (9000, 31, 13)
# 📐 Y 形状: (9000,)
# 📊 标签类别数量分布:
#   类别 0: 1800 个样本
#   类别 1: 1800 个样本
#   类别 2: 1800 个样本
#   类别 3: 1800 个样本
#   类别 4: 1800 个样本
#
# 📁 加载类别：OTHERS
# ✅ X 长度：2770
# ✅ Y 长度：2770
# ✅ X_mfcc 长度：2770
# 📐 X 形状: (2770, 8000)
# 📐 X_mfcc 形状: (2770, 31, 13)
# 📐 Y 形状: (2770,)
# 📊 标签类别数量分布:
#   类别 4: 2770 个样本
#
# 📁 加载类别：PC
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：PHONE
# ✅ X 长度：15000
# ✅ Y 长度：15000
# ✅ X_mfcc 长度：15000
# 📐 X 形状: (15000, 8000)
# 📐 X_mfcc 形状: (15000, 31, 13)
# 📐 Y 形状: (15000,)
# 📊 标签类别数量分布:
#   类别 0: 3000 个样本
#   类别 1: 3000 个样本
#   类别 2: 3000 个样本
#   类别 3: 3000 个样本
#   类别 4: 3000 个样本

# %%
def sample_and_concat(data_dict, length_dict):
    """
    根据指定长度从 data_dict 中每个类别抽样（或补齐），返回拼接后的 X, X_mfcc, Y。

    参数:
        data_dict (dict): 类别 -> {'X': ..., 'X_mfcc': ..., 'Y': ...}
        length_dict (dict): 类别 -> 每类取样数（int）

    返回:
        X_all, X_mfcc_all, Y_all: 拼接后的 numpy 数组
    """
    X_list = []
    X_mfcc_list = []
    Y_list = []

    for cat, n in length_dict.items():
        if cat not in data_dict:
            print(f"⚠️ 类别 {cat} 不在 data_dict 中，跳过。")
            continue

        group = data_dict[cat]
        X = adjust_array_length(group['X'], n)
        X_mfcc = adjust_array_length(group['X_mfcc'], n)
        Y = adjust_array_length(group['Y'], n)

        X_list.append(X)
        X_mfcc_list.append(X_mfcc)
        Y_list.append(Y)

        print(f"✅ 类别 {cat}: 已采样 {n} 条")

    X_all = np.concatenate(X_list, axis=0)
    X_mfcc_all = np.concatenate(X_mfcc_list, axis=0)
    Y_all = np.concatenate(Y_list, axis=0)

    print(f"🎯 合并后总样本数: {len(Y_all)}")
    return X_all, X_mfcc_all, Y_all

# %%
length_dict = {
    'BOARD': 15000,
    'PHONE': 3000,
    'IPAD': 3000,
    'PC': 3000,
    'OTHERS': 2000,
    'DIY': 9000
}

X, X_mfcc, Y = sample_and_concat(data_dict, length_dict)
# Out:
# ✅ 类别 BOARD: 已采样 15000 条
# ✅ 类别 PHONE: 已采样 3000 条
# ✅ 类别 IPAD: 已采样 3000 条
# ✅ 类别 PC: 已采样 3000 条
# ✅ 类别 OTHERS: 已采样 2000 条
# ✅ 类别 DIY: 已采样 9000 条
# 🎯 合并后总样本数: 35000

# %%
output_dir = Path("OFFICIAL_ALL/NO_NOISE")
output_dir.mkdir(parents=True, exist_ok=True)

np.save(output_dir / "X.npy", X)
np.save(output_dir / "X_mfcc.npy", X_mfcc)
np.save(output_dir / "Y.npy", Y)

# %% [markdown]
# ## 加噪声

# %%
def mix_audio_batches(signal_batch, noise_batch, snr_list, normalize_audio_batch):
    """
    从 signal_batch (n, 8000) 和 noise_batch (m, 8000) 中随机混音，按 snr_list 中的 SNR 进行混音，直至 signal_batch 抽完。
    返回: 一个字典，键为 SNR，值为对应混音后的 numpy 数组 (n, 8000)。
    """
    n, _ = signal_batch.shape
    m, _ = noise_batch.shape

    # 随机顺序抽取 signal_batch（不放回）
    signal_indices = np.random.permutation(n)

    # 为每个 SNR 创建空列表
    mixed_audio_dict = {snr: [] for snr in snr_list}

    for idx in signal_indices:
        # 当前信号
        signal = signal_batch[idx]

        # 随机从 noise_batch（有放回）抽一个
        noise_idx = np.random.randint(0, m)
        noise = noise_batch[noise_idx]

        # 计算信号和噪声功率
        signal_power = np.mean(signal ** 2)
        noise_power = np.mean(noise ** 2)

        # 避免除0
        if noise_power == 0:
            noise_power = 1e-12

        for snr in snr_list:
            # 计算缩放因子
            target_noise_power = signal_power / (10 ** (snr / 10))
            scaling_factor = np.sqrt(target_noise_power / noise_power)

            # 混音
            mixed = signal + scaling_factor * noise
            mixed_audio_dict[snr].append(mixed)

    # 转换为 numpy 数组并进行归一化
    for snr in snr_list:
        mixed_audio = np.stack(mixed_audio_dict[snr], axis=0)
        mixed_audio = normalize_audio_batch(mixed_audio)
        mixed_audio_dict[snr] = mixed_audio

    return mixed_audio_dict


def concatenate_mixed_audio(mixed_audio_dict: dict) -> np.ndarray:
    """
    将混音字典中的所有 SNR 的 numpy 数组拼接为一个大的 numpy 数组。
    
    参数:
    mixed_audio_dict: dict，键是 SNR，值是 (n, 8000) 的 numpy 数组。
    
    返回:
    拼接后的 numpy 数组，形状是 (sum_n, 8000)。
    """
    # 取出所有值（每个 numpy 数组）并拼接
    concatenated = np.concatenate(list(mixed_audio_dict.values()), axis=0)
    return concatenated

# %%
# 混音
snr_list = [-3,0,10,100]
mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 混音
#       2 snr_list = [-3,0,10,100]
# ----> 3 mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
#       4 mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
#
# NameError: name 'normalize_audio_batch' is not defined

# %% [markdown]
# # 训练

# %%
root_dir = Path(f'OFFICIAL_ALL/NO_NOISE')

X = np.load(root_dir / "X.npy")
Y = np.load(root_dir / "Y.npy")
X_mfcc = np.load(root_dir / "X_mfcc.npy")

# 打印加载后的数据形状
print("加载后的 X 形状:", X.shape)  
print("加载后的 Y 形状:", Y.shape)
print("加载后的 X_mfcc 形状:", X_mfcc.shape)

# 打印标签  
unique_labels, counts = np.unique(Y, return_counts=True)
label_distribution = dict(zip(unique_labels, counts))
print("标签分布:", label_distribution)
# Out:
# 加载后的 X 形状: (35000, 8000)
# 加载后的 Y 形状: (35000,)
# 加载后的 X_mfcc 形状: (35000, 31, 13)
# 标签分布: {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}

# %%
# 标签重新映射：将0-3的标签都设为0，4的类别设为1
Y_binary = np.where(Y == 4, 1, 0)

# 验证映射结果
print("重新映射前的标签分布:")
unique_labels_old, counts_old = np.unique(Y, return_counts=True)
label_distribution_old = dict(zip(unique_labels_old, counts_old))
print(label_distribution_old)

print("\n重新映射后的标签分布:")
unique_labels_new, counts_new = np.unique(Y_binary, return_counts=True)
label_distribution_new = dict(zip(unique_labels_new, counts_new))
print(label_distribution_new)

# 验证映射是否正确
print(f"\n原来类别0-3的总数: {6591 + 6577 + 6646 + 6602} = {sum([6591, 6577, 6646, 6602])}")
print(f"原来类别4的总数: {8584}")
print(f"新标签0的数量: {label_distribution_new[0]}")
print(f"新标签1的数量: {label_distribution_new[1]}")

# 更新Y为新的二分类标签
Y = Y_binary

print(f"\n最终的Y形状: {Y.shape}")
print(f"最终的标签分布: {dict(zip(*np.unique(Y, return_counts=True)))}")
# Out:
# 重新映射前的标签分布:
# {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}
#
# 重新映射后的标签分布:
# {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}
#
# 原来类别0-3的总数: 26416 = 26416
# 原来类别4的总数: 8584
# 新标签0的数量: 26416
# 新标签1的数量: 8584
#
# 最终的Y形状: (35000,)
# 最终的标签分布: {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}

# %%
print("去掉第一维前形状:", X_mfcc.shape)
X_mfcc_no_first = X_mfcc[:, :, 1:]
print("去掉第一维后形状:", X_mfcc_no_first.shape)
X_mfcc_no_first = X_mfcc_no_first.reshape(X_mfcc_no_first.shape[0], 31, 12, 1)  
print("X_mfcc 形状:", X_mfcc_no_first.shape)
# Out:
# 去掉第一维前形状: (35000, 31, 13)
# 去掉第一维后形状: (35000, 31, 12)
# X_mfcc 形状: (35000, 31, 12, 1)

# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
def create_speaker_model():
    # 定义输入
    inputs = tf.keras.Input(shape=(31, 12, 1))
    
    # 逐层传递x
    # 第一步：Conv2D卷积操作（不包含激活函数）
    x = tf.keras.layers.Conv2D(512, kernel_size=(9, 12), padding='valid')(inputs)
    # 第二步：单独应用ReLU激活函数
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(23, 1), padding='valid')(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(2, activation='softmax')(x)
    
    # 创建模型
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model
# 量化转换函数
def quantize_model(model, X_sample):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type = tf.int8
    converter.inference_output_type = tf.int8

    def representative_dataset():
        for i in range(min(100, len(X_sample))):
            data = X_sample[i:i+1]
            yield [tf.cast(data, tf.float32)]
    
    converter.representative_dataset = representative_dataset
    tflite_quant_model = converter.convert()
    return tflite_quant_model


# 数据划分
spk_X_train, spk_X_val, spk_Y_train, spk_Y_val = train_test_split(X_mfcc_no_first, Y, test_size=0.1, random_state=58) #42

# 标签 one-hot

spk_Y_train_cat = tf.keras.utils.to_categorical(spk_Y_train, num_classes=2)
spk_Y_val_cat = tf.keras.utils.to_categorical(spk_Y_val, num_classes=2)

# 创建模型
spk_model = create_speaker_model()

# 编译
spk_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 训练
print("\n开始训练 说话人识别模型")
class_weight = {0: 8584, 1: 26416}  
from tensorflow.keras.callbacks import EarlyStopping
# 配置 EarlyStopping 回调
earlystop = EarlyStopping(
    monitor='val_accuracy',       # 监控的指标，常用 'val_loss' 或 'val_accuracy'
    patience=100,               # 容忍多少个 epoch 没有提升
    restore_best_weights=True, # 回到验证集表现最好的模型
    verbose=1                 # 显示早停信息
)
spk_history = spk_model.fit(
    spk_X_train, spk_Y_train_cat,
    validation_data=(spk_X_val, spk_Y_val_cat),
    epochs=1000,
    batch_size=32,
    callbacks=[earlystop],     # 添加回调函数
    class_weight=class_weight
)

# 量化转换
print("量化 说话人识别模型")
spk_quant_tflite = quantize_model(spk_model, spk_X_train[:10000])  # 添加一个维度以匹配输入形状 (n, 31, 13, 1)
file_path = "spk-OFFICIAL_ALL-NO_NOISE_hid512_9X12_epoch500_2cls_seed58_val_accuracy.tflite"
with open(file_path, "wb") as f:
    f.write(spk_quant_tflite)

print(f"\n✅ 两个模型已训练并量化完成！文件: {file_path}")
# Out:
# 开始训练 说话人识别模型
# Epoch 1/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6409 - loss: 8071.5947 - val_accuracy: 0.7000 - val_loss: 0.5676
# Epoch 2/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7242 - loss: 7080.2764 - val_accuracy: 0.7597 - val_loss: 0.5120
# Epoch 3/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7494 - loss: 6734.6401 - val_accuracy: 0.6954 - val_loss: 0.5511
# Epoch 4/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7559 - loss: 6492.6665 - val_accuracy: 0.7677 - val_loss: 0.4978
# Epoch 5/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7743 - loss: 6285.6362 - val_accuracy: 0.7691 - val_loss: 0.4679
# Epoch 6/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7804 - loss: 6072.6904 - val_accuracy: 0.7649 - val_loss: 0.5034
# Epoch 7/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7892 - loss: 5968.0894 - val_accuracy: 0.7366 - val_loss: 0.5245
# Epoch 8/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7934 - loss: 5870.6709 - val_accuracy: 0.7366 - val_loss: 0.5387
# Epoch 9/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7960 - loss: 5774.5728 - val_accuracy: 0.7880 - val_loss: 0.4621
# Epoch 10/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8105 - loss: 5544.3032 - val_accuracy: 0.7763 - val_loss: 0.4802
# Epoch 11/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8069 - loss: 5529.7778 - val_accuracy: 0.8211 - val_loss: 0.4202
# Epoch 12/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8184 - loss: 5405.0879 - val_accuracy: 0.7866 - val_loss: 0.4581
# Epoch 13/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8164 - loss: 5314.4980 - val_accuracy: 0.7566 - val_loss: 0.4835
# Epoch 14/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8221 - loss: 5165.9580 - val_accuracy: 0.7649 - val_loss: 0.4762
# Epoch 15/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8193 - loss: 5133.9639 - val_accuracy: 0.7409 - val_loss: 0.5039
# Epoch 16/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8228 - loss: 5043.5649 - val_accuracy: 0.7954 - val_loss: 0.4487
# Epoch 17/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8329 - loss: 4927.4399 - val_accuracy: 0.7754 - val_loss: 0.4751
# Epoch 18/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8300 - loss: 4884.3862 - val_accuracy: 0.7777 - val_loss: 0.4814
# Epoch 19/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8355 - loss: 4920.6313 - val_accuracy: 0.7574 - val_loss: 0.4798
# Epoch 20/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8321 - loss: 4841.9619 - val_accuracy: 0.8174 - val_loss: 0.4242
# Epoch 21/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8334 - loss: 4803.8843 - val_accuracy: 0.7829 - val_loss: 0.4857
# Epoch 22/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8384 - loss: 4734.7866 - val_accuracy: 0.7886 - val_loss: 0.4567
# Epoch 23/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8404 - loss: 4606.1758 - val_accuracy: 0.7751 - val_loss: 0.4811
# Epoch 24/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8464 - loss: 4490.3428 - val_accuracy: 0.7626 - val_loss: 0.5049
# Epoch 25/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8529 - loss: 4392.6797 - val_accuracy: 0.7723 - val_loss: 0.4873
# Epoch 26/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8467 - loss: 4444.9658 - val_accuracy: 0.7740 - val_loss: 0.4632
# Epoch 27/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8541 - loss: 4293.9141 - val_accuracy: 0.8234 - val_loss: 0.4248
# Epoch 28/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8586 - loss: 4176.8945 - val_accuracy: 0.7889 - val_loss: 0.4772
# Epoch 29/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8580 - loss: 4208.6831 - val_accuracy: 0.7883 - val_loss: 0.4754
# Epoch 30/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8561 - loss: 4182.6875 - val_accuracy: 0.7954 - val_loss: 0.4731
# Epoch 31/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8599 - loss: 4091.4343 - val_accuracy: 0.7531 - val_loss: 0.4913
# Epoch 32/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8603 - loss: 4056.0168 - val_accuracy: 0.7857 - val_loss: 0.4892
# Epoch 33/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8693 - loss: 3922.5667 - val_accuracy: 0.8080 - val_loss: 0.4479
# Epoch 34/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8630 - loss: 4024.0103 - val_accuracy: 0.7686 - val_loss: 0.5035
# Epoch 35/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8645 - loss: 3992.8149 - val_accuracy: 0.7720 - val_loss: 0.4937
# Epoch 36/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8654 - loss: 3912.5823 - val_accuracy: 0.7763 - val_loss: 0.4902
# Epoch 37/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8650 - loss: 3886.7178 - val_accuracy: 0.7549 - val_loss: 0.5385
# Epoch 38/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8741 - loss: 3793.0674 - val_accuracy: 0.7909 - val_loss: 0.4685
# Epoch 39/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8686 - loss: 3846.8352 - val_accuracy: 0.7977 - val_loss: 0.4777
# Epoch 40/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8770 - loss: 3681.9895 - val_accuracy: 0.8111 - val_loss: 0.4567
# Epoch 41/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8763 - loss: 3724.5540 - val_accuracy: 0.7977 - val_loss: 0.5125
# Epoch 42/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8747 - loss: 3794.6448 - val_accuracy: 0.8103 - val_loss: 0.4614
# Epoch 43/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8839 - loss: 3483.0881 - val_accuracy: 0.7766 - val_loss: 0.5306
# Epoch 44/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8750 - loss: 3621.8215 - val_accuracy: 0.8066 - val_loss: 0.4682
# Epoch 45/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8826 - loss: 3532.2483 - val_accuracy: 0.7771 - val_loss: 0.5108
# Epoch 46/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8796 - loss: 3548.9099 - val_accuracy: 0.8003 - val_loss: 0.4940
# Epoch 47/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8809 - loss: 3617.0632 - val_accuracy: 0.7791 - val_loss: 0.5036
# Epoch 48/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8797 - loss: 3490.8357 - val_accuracy: 0.7183 - val_loss: 0.6596
# Epoch 49/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8830 - loss: 3428.1257 - val_accuracy: 0.7649 - val_loss: 0.5355
# Epoch 50/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8848 - loss: 3450.6682 - val_accuracy: 0.7874 - val_loss: 0.5471
# Epoch 51/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8811 - loss: 3498.5771 - val_accuracy: 0.7917 - val_loss: 0.5250
# Epoch 52/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8898 - loss: 3358.2300 - val_accuracy: 0.7729 - val_loss: 0.5288
# Epoch 53/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8837 - loss: 3430.6506 - val_accuracy: 0.7691 - val_loss: 0.5346
# Epoch 54/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8873 - loss: 3356.3242 - val_accuracy: 0.7640 - val_loss: 0.5607
# Epoch 55/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8878 - loss: 3326.8923 - val_accuracy: 0.7751 - val_loss: 0.5278
# Epoch 56/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8922 - loss: 3292.6284 - val_accuracy: 0.7677 - val_loss: 0.5603
# Epoch 57/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8916 - loss: 3237.5273 - val_accuracy: 0.7826 - val_loss: 0.5751
# Epoch 58/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8883 - loss: 3320.9006 - val_accuracy: 0.7966 - val_loss: 0.5334
# Epoch 59/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8927 - loss: 3191.4958 - val_accuracy: 0.8066 - val_loss: 0.5039
# Epoch 60/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8950 - loss: 3162.6873 - val_accuracy: 0.7783 - val_loss: 0.5919
# Epoch 61/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8938 - loss: 3259.3667 - val_accuracy: 0.7637 - val_loss: 0.6056
# Epoch 62/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8895 - loss: 3308.6897 - val_accuracy: 0.7729 - val_loss: 0.5672
# Epoch 63/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8953 - loss: 3090.8999 - val_accuracy: 0.7866 - val_loss: 0.5430
# Epoch 64/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8956 - loss: 3091.1792 - val_accuracy: 0.7740 - val_loss: 0.5559
# Epoch 65/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8958 - loss: 3104.4485 - val_accuracy: 0.7520 - val_loss: 0.6295
# Epoch 66/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8927 - loss: 3227.0056 - val_accuracy: 0.7751 - val_loss: 0.5712
# Epoch 67/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8969 - loss: 3112.4973 - val_accuracy: 0.7871 - val_loss: 0.5733
# Epoch 68/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8975 - loss: 3003.3997 - val_accuracy: 0.8083 - val_loss: 0.5634
# Epoch 69/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8961 - loss: 3106.7961 - val_accuracy: 0.7809 - val_loss: 0.5471
# Epoch 70/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8951 - loss: 3133.1970 - val_accuracy: 0.8117 - val_loss: 0.5433
# Epoch 71/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8972 - loss: 3064.2275 - val_accuracy: 0.7926 - val_loss: 0.5939
# Epoch 72/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8941 - loss: 3162.2336 - val_accuracy: 0.7714 - val_loss: 0.5678
# Epoch 73/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9056 - loss: 2919.5850 - val_accuracy: 0.8060 - val_loss: 0.5365
# Epoch 74/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8986 - loss: 3034.9922 - val_accuracy: 0.7791 - val_loss: 0.5822
# Epoch 75/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8991 - loss: 2961.2739 - val_accuracy: 0.7600 - val_loss: 0.6830
# Epoch 76/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8958 - loss: 3080.0647 - val_accuracy: 0.7889 - val_loss: 0.5643
# Epoch 77/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9028 - loss: 2936.8933 - val_accuracy: 0.7780 - val_loss: 0.6066
# Epoch 78/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9025 - loss: 2907.2498 - val_accuracy: 0.7914 - val_loss: 0.5883
# Epoch 79/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9005 - loss: 2941.5146 - val_accuracy: 0.8091 - val_loss: 0.6370
# Epoch 80/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9026 - loss: 2889.8027 - val_accuracy: 0.7857 - val_loss: 0.6092
# Epoch 81/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9025 - loss: 2950.1143 - val_accuracy: 0.7646 - val_loss: 0.6287
# Epoch 82/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9050 - loss: 2830.9817 - val_accuracy: 0.8083 - val_loss: 0.5856
# Epoch 83/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9034 - loss: 2896.7324 - val_accuracy: 0.7851 - val_loss: 0.5839
# Epoch 84/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8994 - loss: 2912.7878 - val_accuracy: 0.7897 - val_loss: 0.5917
# Epoch 85/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9050 - loss: 2818.6084 - val_accuracy: 0.7894 - val_loss: 0.5841
# Epoch 86/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9048 - loss: 2879.7539 - val_accuracy: 0.8086 - val_loss: 0.5703
# Epoch 87/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9050 - loss: 2795.3647 - val_accuracy: 0.7911 - val_loss: 0.5990
# Epoch 88/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9071 - loss: 2783.3198 - val_accuracy: 0.7583 - val_loss: 0.6555
# Epoch 89/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9046 - loss: 2852.2864 - val_accuracy: 0.7789 - val_loss: 0.6299
# Epoch 90/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9065 - loss: 2750.0605 - val_accuracy: 0.7891 - val_loss: 0.6243
# Epoch 91/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9052 - loss: 2847.2036 - val_accuracy: 0.8129 - val_loss: 0.5890
# Epoch 92/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9066 - loss: 2742.9875 - val_accuracy: 0.7866 - val_loss: 0.6271
# Epoch 93/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9081 - loss: 2766.3796 - val_accuracy: 0.7980 - val_loss: 0.5924
# Epoch 94/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9138 - loss: 2635.1174 - val_accuracy: 0.7729 - val_loss: 0.6224
# Epoch 95/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9084 - loss: 2776.1887 - val_accuracy: 0.7411 - val_loss: 0.8005
# Epoch 96/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9032 - loss: 2972.6655 - val_accuracy: 0.7917 - val_loss: 0.5957
# Epoch 97/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9063 - loss: 2795.6912 - val_accuracy: 0.7911 - val_loss: 0.6100
# Epoch 98/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9050 - loss: 2781.3882 - val_accuracy: 0.7751 - val_loss: 0.6280
# Epoch 99/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9072 - loss: 2749.9109 - val_accuracy: 0.7926 - val_loss: 0.5939
# Epoch 100/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9099 - loss: 2597.9678 - val_accuracy: 0.7700 - val_loss: 0.6559
# Epoch 101/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9094 - loss: 2765.1619 - val_accuracy: 0.7923 - val_loss: 0.6010
# Epoch 102/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9079 - loss: 2729.0293 - val_accuracy: 0.7909 - val_loss: 0.6209
# Epoch 103/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9112 - loss: 2646.9238 - val_accuracy: 0.7963 - val_loss: 0.6246
# Epoch 104/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9093 - loss: 2700.1414 - val_accuracy: 0.8197 - val_loss: 0.6123
# Epoch 105/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9156 - loss: 2550.8032 - val_accuracy: 0.8194 - val_loss: 0.6428
# Epoch 106/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9095 - loss: 2794.4177 - val_accuracy: 0.8034 - val_loss: 0.7716
# Epoch 107/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9084 - loss: 2877.0916 - val_accuracy: 0.7594 - val_loss: 0.6950
# Epoch 108/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9123 - loss: 2543.6465 - val_accuracy: 0.7977 - val_loss: 0.6529
# Epoch 109/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9049 - loss: 2722.8442 - val_accuracy: 0.7606 - val_loss: 0.6599
# Epoch 110/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9102 - loss: 2596.0156 - val_accuracy: 0.7803 - val_loss: 0.6388
# Epoch 111/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9103 - loss: 2679.6643 - val_accuracy: 0.7863 - val_loss: 0.6563
# Epoch 112/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9106 - loss: 2740.0615 - val_accuracy: 0.7806 - val_loss: 0.6410
# Epoch 113/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9113 - loss: 2618.2573 - val_accuracy: 0.7954 - val_loss: 0.6415
# Epoch 114/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9109 - loss: 2635.4045 - val_accuracy: 0.7986 - val_loss: 0.6537
# Epoch 115/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9120 - loss: 2693.1611 - val_accuracy: 0.7817 - val_loss: 0.6332
# Epoch 116/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9125 - loss: 2573.7058 - val_accuracy: 0.7606 - val_loss: 0.6951
# Epoch 117/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9088 - loss: 2690.3215 - val_accuracy: 0.7743 - val_loss: 0.6718
# Epoch 118/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9139 - loss: 2586.2019 - val_accuracy: 0.7837 - val_loss: 0.6496
# Epoch 119/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9098 - loss: 2599.0283 - val_accuracy: 0.7983 - val_loss: 0.6554
# Epoch 120/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9141 - loss: 2512.6287 - val_accuracy: 0.8094 - val_loss: 0.6545
# Epoch 121/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9095 - loss: 2635.3706 - val_accuracy: 0.7991 - val_loss: 0.6205
# Epoch 122/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9136 - loss: 2595.4456 - val_accuracy: 0.7617 - val_loss: 0.7511
# Epoch 123/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9093 - loss: 2772.2119 - val_accuracy: 0.7817 - val_loss: 0.6732
# Epoch 124/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9155 - loss: 2479.8335 - val_accuracy: 0.7720 - val_loss: 0.7444
# Epoch 125/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9142 - loss: 2496.6421 - val_accuracy: 0.7854 - val_loss: 0.6589
# Epoch 126/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9165 - loss: 2522.4392 - val_accuracy: 0.7694 - val_loss: 0.6967
# Epoch 127/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9169 - loss: 2511.7354 - val_accuracy: 0.7671 - val_loss: 0.7069
# Epoch 127: early stopping
# Restoring model weights from the end of the best epoch: 27.
# 量化 说话人识别模型
# INFO:tensorflow:Assets written to: /tmp/tmpzf3xvn8w/assets
# INFO:tensorflow:Assets written to: /tmp/tmpzf3xvn8w/assets
# Saved artifact at '/tmp/tmpzf3xvn8w'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 31, 12, 1), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   140613881329424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140613881320016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140613881329232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140613881315408: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/lidonghaowsl/miniconda3/envs/vesc2025-algo/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1753286424.416361   10123 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753286424.416380   10123 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-24 00:00:24.416547: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpzf3xvn8w
# 2025-07-24 00:00:24.416893: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-24 00:00:24.416902: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpzf3xvn8w
# 2025-07-24 00:00:24.420354: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-24 00:00:24.440559: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpzf3xvn8w
# 2025-07-24 00:00:24.446602: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 30056 microseconds.
# ✅ 两个模型已训练并量化完成！文件: spk-OFFICIAL_ALL-NO_NOISE_hid512_9X12_epoch500_2cls_seed58_val_accuracy.tflite
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
