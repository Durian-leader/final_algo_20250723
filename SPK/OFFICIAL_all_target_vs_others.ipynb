# %%
import os
import random
import shutil
from pathlib import Path
import numpy as np
import torch
import torchaudio
import soundfile as sf
from multiprocessing import Pool, cpu_count
import multiprocessing as mp
from silero_vad import load_silero_vad
from IPython.display import Audio
from scipy.fft import rfft, fft

# %%
import numpy as np

def adjust_array_length(arr: np.ndarray, n: int) -> np.ndarray:
    """
    调整输入数组的长度为 n。
    - 若 arr 长度 >= n，则随机抽取 n 个元素（不放回）；
    - 若 arr 长度 < n，则补齐至 n，补充部分来自于 arr 的随机采样（放回）。

    参数:
        arr (np.ndarray): 输入的一维或二维数组（假设按第一个维度为样本维）。
        n (int): 目标长度。

    返回:
        np.ndarray: 调整后的数组，长度为 n。
    """
    arr_len = len(arr)
    if arr_len >= n:
        idx = np.random.choice(arr_len, n, replace=False)
        return arr[idx]
    else:
        deficit = n - arr_len
        idx = np.random.choice(arr_len, deficit, replace=True)
        extra_arr = arr[idx]
        return np.concatenate([arr, extra_arr], axis=0)

# %%
import numpy as np
from collections import Counter

# NOISE
X_NOISE = np.load('OFFICIAL/NOISE/03mfcc/X.npy')
Y_NOISE = np.load('OFFICIAL/NOISE/03mfcc/Y.npy')

# 打印样本数量
print(f'✅ X_NOISE 长度：{len(X_NOISE)}')
print(f'✅ Y_NOISE 长度：{len(Y_NOISE)}')

# 打印形状（假设是 numpy 数组）
print(f'📐 X_NOISE 形状: {X_NOISE.shape}')          # e.g. (13600, 8000)
print(f'📐 Y_NOISE 形状: {Y_NOISE.shape}')          # e.g. (13600,)

# 打印标签各类数量
label_counts = Counter(Y_NOISE)
print('📊 标签类别数量分布:')
for label, count in sorted(label_counts.items()):
    print(f'  类别 {label}: {count} 个样本')
# Out:
# ✅ X_NOISE 长度：7000
# ✅ Y_NOISE 长度：7000
# 📐 X_NOISE 形状: (7000, 8000)
# 📐 Y_NOISE 形状: (7000,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 1000 个样本
#   类别 2: 500 个样本
#   类别 3: 1000 个样本
#   类别 4: 1000 个样本
#   类别 5: 3000 个样本

# %%
import numpy as np
from collections import Counter
from pathlib import Path

categories = ['BOARD', 'IPAD', 'DIY', 'OTHERS', 'PC', 'PHONE']
base_path = Path('OFFICIAL')

# 数据字典：每类一个子字典，包含 X, X_mfcc, Y
data_dict = {}

for cat in categories:
    prefix = cat.upper()
    folder = base_path / prefix / '03mfcc'
    try:
        # 加载数据
        X = np.load(folder / 'X.npy')
        X_mfcc = np.load(folder / 'X_mfcc.npy')
        Y = np.load(folder / 'Y.npy')

        # 存入字典
        data_dict[prefix] = {
            'X': X,
            'X_mfcc': X_mfcc,
            'Y': Y
        }

        # 打印信息
        print(f'\n📁 加载类别：{prefix}')
        print(f'✅ X 长度：{len(X)}')
        print(f'✅ Y 长度：{len(Y)}')
        print(f'✅ X_mfcc 长度：{len(X_mfcc)}')
        print(f'📐 X 形状: {X.shape}')
        print(f'📐 X_mfcc 形状: {X_mfcc.shape}')
        print(f'📐 Y 形状: {Y.shape}')

        # 标签统计
        label_counts = Counter(Y)
        print('📊 标签类别数量分布:')
        for label, count in sorted(label_counts.items()):
            print(f'  类别 {label}: {count} 个样本')

    except FileNotFoundError as e:
        print(f'❌ 类别 {prefix} 加载失败: {e}')
# Out:
# 📁 加载类别：BOARD
# ✅ X 长度：14500
# ✅ Y 长度：14500
# ✅ X_mfcc 长度：14500
# 📐 X 形状: (14500, 8000)
# 📐 X_mfcc 形状: (14500, 31, 13)
# 📐 Y 形状: (14500,)
# 📊 标签类别数量分布:
#   类别 0: 2900 个样本
#   类别 1: 2900 个样本
#   类别 2: 2900 个样本
#   类别 3: 2900 个样本
#   类别 4: 2900 个样本
#
# 📁 加载类别：IPAD
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：DIY
# ✅ X 长度：9000
# ✅ Y 长度：9000
# ✅ X_mfcc 长度：9000
# 📐 X 形状: (9000, 8000)
# 📐 X_mfcc 形状: (9000, 31, 13)
# 📐 Y 形状: (9000,)
# 📊 标签类别数量分布:
#   类别 0: 1800 个样本
#   类别 1: 1800 个样本
#   类别 2: 1800 个样本
#   类别 3: 1800 个样本
#   类别 4: 1800 个样本
#
# 📁 加载类别：OTHERS
# ✅ X 长度：2770
# ✅ Y 长度：2770
# ✅ X_mfcc 长度：2770
# 📐 X 形状: (2770, 8000)
# 📐 X_mfcc 形状: (2770, 31, 13)
# 📐 Y 形状: (2770,)
# 📊 标签类别数量分布:
#   类别 4: 2770 个样本
#
# 📁 加载类别：PC
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：PHONE
# ✅ X 长度：15000
# ✅ Y 长度：15000
# ✅ X_mfcc 长度：15000
# 📐 X 形状: (15000, 8000)
# 📐 X_mfcc 形状: (15000, 31, 13)
# 📐 Y 形状: (15000,)
# 📊 标签类别数量分布:
#   类别 0: 3000 个样本
#   类别 1: 3000 个样本
#   类别 2: 3000 个样本
#   类别 3: 3000 个样本
#   类别 4: 3000 个样本

# %%
def sample_and_concat(data_dict, length_dict):
    """
    根据指定长度从 data_dict 中每个类别抽样（或补齐），返回拼接后的 X, X_mfcc, Y。

    参数:
        data_dict (dict): 类别 -> {'X': ..., 'X_mfcc': ..., 'Y': ...}
        length_dict (dict): 类别 -> 每类取样数（int）

    返回:
        X_all, X_mfcc_all, Y_all: 拼接后的 numpy 数组
    """
    X_list = []
    X_mfcc_list = []
    Y_list = []

    for cat, n in length_dict.items():
        if cat not in data_dict:
            print(f"⚠️ 类别 {cat} 不在 data_dict 中，跳过。")
            continue

        group = data_dict[cat]
        X = adjust_array_length(group['X'], n)
        X_mfcc = adjust_array_length(group['X_mfcc'], n)
        Y = adjust_array_length(group['Y'], n)

        X_list.append(X)
        X_mfcc_list.append(X_mfcc)
        Y_list.append(Y)

        print(f"✅ 类别 {cat}: 已采样 {n} 条")

    X_all = np.concatenate(X_list, axis=0)
    X_mfcc_all = np.concatenate(X_mfcc_list, axis=0)
    Y_all = np.concatenate(Y_list, axis=0)

    print(f"🎯 合并后总样本数: {len(Y_all)}")
    return X_all, X_mfcc_all, Y_all

# %%
length_dict = {
    'BOARD': 15000,
    'PHONE': 3000,
    'IPAD': 3000,
    'PC': 3000,
    'OTHERS': 2000,
    'DIY': 9000
}

X, X_mfcc, Y = sample_and_concat(data_dict, length_dict)
# Out:
# ✅ 类别 BOARD: 已采样 15000 条
# ✅ 类别 PHONE: 已采样 3000 条
# ✅ 类别 IPAD: 已采样 3000 条
# ✅ 类别 PC: 已采样 3000 条
# ✅ 类别 OTHERS: 已采样 2000 条
# ✅ 类别 DIY: 已采样 9000 条
# 🎯 合并后总样本数: 35000

# %%
output_dir = Path("OFFICIAL_ALL/NO_NOISE")
output_dir.mkdir(parents=True, exist_ok=True)

np.save(output_dir / "X.npy", X)
np.save(output_dir / "X_mfcc.npy", X_mfcc)
np.save(output_dir / "Y.npy", Y)

# %% [markdown]
# ## 加噪声

# %%
def mix_audio_batches(signal_batch, noise_batch, snr_list, normalize_audio_batch):
    """
    从 signal_batch (n, 8000) 和 noise_batch (m, 8000) 中随机混音，按 snr_list 中的 SNR 进行混音，直至 signal_batch 抽完。
    返回: 一个字典，键为 SNR，值为对应混音后的 numpy 数组 (n, 8000)。
    """
    n, _ = signal_batch.shape
    m, _ = noise_batch.shape

    # 随机顺序抽取 signal_batch（不放回）
    signal_indices = np.random.permutation(n)

    # 为每个 SNR 创建空列表
    mixed_audio_dict = {snr: [] for snr in snr_list}

    for idx in signal_indices:
        # 当前信号
        signal = signal_batch[idx]

        # 随机从 noise_batch（有放回）抽一个
        noise_idx = np.random.randint(0, m)
        noise = noise_batch[noise_idx]

        # 计算信号和噪声功率
        signal_power = np.mean(signal ** 2)
        noise_power = np.mean(noise ** 2)

        # 避免除0
        if noise_power == 0:
            noise_power = 1e-12

        for snr in snr_list:
            # 计算缩放因子
            target_noise_power = signal_power / (10 ** (snr / 10))
            scaling_factor = np.sqrt(target_noise_power / noise_power)

            # 混音
            mixed = signal + scaling_factor * noise
            mixed_audio_dict[snr].append(mixed)

    # 转换为 numpy 数组并进行归一化
    for snr in snr_list:
        mixed_audio = np.stack(mixed_audio_dict[snr], axis=0)
        mixed_audio = normalize_audio_batch(mixed_audio)
        mixed_audio_dict[snr] = mixed_audio

    return mixed_audio_dict


def concatenate_mixed_audio(mixed_audio_dict: dict) -> np.ndarray:
    """
    将混音字典中的所有 SNR 的 numpy 数组拼接为一个大的 numpy 数组。
    
    参数:
    mixed_audio_dict: dict，键是 SNR，值是 (n, 8000) 的 numpy 数组。
    
    返回:
    拼接后的 numpy 数组，形状是 (sum_n, 8000)。
    """
    # 取出所有值（每个 numpy 数组）并拼接
    concatenated = np.concatenate(list(mixed_audio_dict.values()), axis=0)
    return concatenated

# %%
# 混音
snr_list = [-3,0,10,100]
mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 混音
#       2 snr_list = [-3,0,10,100]
# ----> 3 mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
#       4 mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
#
# NameError: name 'normalize_audio_batch' is not defined

# %% [markdown]
# # 训练

# %%
root_dir = Path(f'OFFICIAL_ALL/NO_NOISE')

X = np.load(root_dir / "X.npy")
Y = np.load(root_dir / "Y.npy")
X_mfcc = np.load(root_dir / "X_mfcc.npy")

# 打印加载后的数据形状
print("加载后的 X 形状:", X.shape)  
print("加载后的 Y 形状:", Y.shape)
print("加载后的 X_mfcc 形状:", X_mfcc.shape)

# 打印标签  
unique_labels, counts = np.unique(Y, return_counts=True)
label_distribution = dict(zip(unique_labels, counts))
print("标签分布:", label_distribution)
# Out:
# 加载后的 X 形状: (35000, 8000)
# 加载后的 Y 形状: (35000,)
# 加载后的 X_mfcc 形状: (35000, 31, 13)
# 标签分布: {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}

# %%
# 标签重新映射：将0-3的标签都设为0，4的类别设为1
Y_binary = np.where(Y == 4, 1, 0)

# 验证映射结果
print("重新映射前的标签分布:")
unique_labels_old, counts_old = np.unique(Y, return_counts=True)
label_distribution_old = dict(zip(unique_labels_old, counts_old))
print(label_distribution_old)

print("\n重新映射后的标签分布:")
unique_labels_new, counts_new = np.unique(Y_binary, return_counts=True)
label_distribution_new = dict(zip(unique_labels_new, counts_new))
print(label_distribution_new)

# 验证映射是否正确
print(f"\n原来类别0-3的总数: {6591 + 6577 + 6646 + 6602} = {sum([6591, 6577, 6646, 6602])}")
print(f"原来类别4的总数: {8584}")
print(f"新标签0的数量: {label_distribution_new[0]}")
print(f"新标签1的数量: {label_distribution_new[1]}")

# 更新Y为新的二分类标签
Y = Y_binary

print(f"\n最终的Y形状: {Y.shape}")
print(f"最终的标签分布: {dict(zip(*np.unique(Y, return_counts=True)))}")
# Out:
# 重新映射前的标签分布:
# {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}
#
# 重新映射后的标签分布:
# {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}
#
# 原来类别0-3的总数: 26416 = 26416
# 原来类别4的总数: 8584
# 新标签0的数量: 26416
# 新标签1的数量: 8584
#
# 最终的Y形状: (35000,)
# 最终的标签分布: {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}

# %%
print("去掉第一维前形状:", X_mfcc.shape)
X_mfcc_no_first = X_mfcc[:, :, 1:]
print("去掉第一维后形状:", X_mfcc_no_first.shape)
X_mfcc_no_first = X_mfcc_no_first.reshape(X_mfcc_no_first.shape[0], 31, 12, 1)  
print("X_mfcc 形状:", X_mfcc_no_first.shape)
# Out:
# 去掉第一维前形状: (35000, 31, 13)
# 去掉第一维后形状: (35000, 31, 12)
# X_mfcc 形状: (35000, 31, 12, 1)

# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
# 说话人识别模型（修正：使用 padding='same'）
def create_speaker_model():
    # 定义输入
    inputs = tf.keras.Input(shape=(31, 12, 1))
    
    # 逐层传递x
    # 第一步：Conv2D卷积操作（不包含激活函数）
    x = tf.keras.layers.Conv2D(52, kernel_size=(7, 12), padding='valid')(inputs)
    # 第二步：单独应用ReLU激活函数
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(25, 1), padding='valid')(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(2, activation='softmax')(x)
    
    # 创建模型
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model
# 量化转换函数
def quantize_model(model, X_sample):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type = tf.int8
    converter.inference_output_type = tf.int8

    def representative_dataset():
        for i in range(min(100, len(X_sample))):
            data = X_sample[i:i+1]
            yield [tf.cast(data, tf.float32)]
    
    converter.representative_dataset = representative_dataset
    tflite_quant_model = converter.convert()
    return tflite_quant_model


# 数据划分
spk_X_train, spk_X_val, spk_Y_train, spk_Y_val = train_test_split(X_mfcc_no_first, Y, test_size=0.1, random_state=58) #42

# 标签 one-hot

spk_Y_train_cat = tf.keras.utils.to_categorical(spk_Y_train, num_classes=2)
spk_Y_val_cat = tf.keras.utils.to_categorical(spk_Y_val, num_classes=2)

# 创建模型
spk_model = create_speaker_model()

# 编译
spk_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 训练
print("\n开始训练 说话人识别模型")
class_weight = {0: 8584, 1: 26416}  # 类别 1、2 权重更高
from tensorflow.keras.callbacks import EarlyStopping
# 配置 EarlyStopping 回调
earlystop = EarlyStopping(
    monitor='val_loss',       # 监控的指标，常用 'val_loss' 或 'val_accuracy'
    patience=20,               # 容忍多少个 epoch 没有提升
    restore_best_weights=True, # 回到验证集表现最好的模型
    verbose=1                 # 显示早停信息
)
spk_history = spk_model.fit(
    spk_X_train, spk_Y_train_cat,
    validation_data=(spk_X_val, spk_Y_val_cat),
    epochs=100,
    batch_size=32,
    callbacks=[earlystop],     # 添加回调函数
    class_weight=class_weight
)

# 量化转换
print("量化 说话人识别模型")
spk_quant_tflite = quantize_model(spk_model, spk_X_train[:1000])  # 添加一个维度以匹配输入形状 (n, 31, 13, 1)
file_path = "spk-OFFICIAL_ALL-NO_NOISE_hid512_7X12_epoch100_2cls_seed58.tflite"
with open(file_path, "wb") as f:
    f.write(spk_quant_tflite)

print(f"\n✅ 两个模型已训练并量化完成！文件: {file_path}")
# Out:
# 2025-07-23 22:17:40.274151: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-23 22:17:40.289000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753280260.307154   79567 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753280260.312648   79567 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753280260.326544   79567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753280260.326562   79567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753280260.326563   79567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753280260.326565   79567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-23 22:17:40.331765: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1753280265.034723   79567 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45763 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:73:00.0, compute capability: 8.6
# 开始训练 说话人识别模型
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753280268.352034   79905 service.cc:152] XLA service 0x7fce70018c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753280268.352076   79905 service.cc:160]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-07-23 22:17:48.400511: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753280268.516819   79905 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  34/985 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4394 - loss: 9475.1670
# I0000 00:00:1753280270.678913   79905 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.6310 - loss: 8150.2036 - val_accuracy: 0.6589 - val_loss: 0.6169
# Epoch 2/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7098 - loss: 7450.7441 - val_accuracy: 0.7220 - val_loss: 0.5539
# Epoch 3/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7321 - loss: 7014.8110 - val_accuracy: 0.7263 - val_loss: 0.5352
# Epoch 4/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7463 - loss: 6778.3672 - val_accuracy: 0.6814 - val_loss: 0.5805
# Epoch 5/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7579 - loss: 6618.0244 - val_accuracy: 0.7409 - val_loss: 0.5161
# Epoch 6/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7670 - loss: 6458.7197 - val_accuracy: 0.7834 - val_loss: 0.4809
# Epoch 7/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7700 - loss: 6349.3262 - val_accuracy: 0.7160 - val_loss: 0.5479
# Epoch 8/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7641 - loss: 6357.2622 - val_accuracy: 0.7817 - val_loss: 0.4688
# Epoch 9/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7819 - loss: 6163.5400 - val_accuracy: 0.7720 - val_loss: 0.4737
# Epoch 10/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7698 - loss: 6210.0356 - val_accuracy: 0.7969 - val_loss: 0.4519
# Epoch 11/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7826 - loss: 6141.9453 - val_accuracy: 0.7863 - val_loss: 0.4640
# Epoch 12/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7841 - loss: 6091.7300 - val_accuracy: 0.7969 - val_loss: 0.4539
# Epoch 13/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7915 - loss: 5956.3828 - val_accuracy: 0.7826 - val_loss: 0.4761
# Epoch 14/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7885 - loss: 5997.1348 - val_accuracy: 0.8069 - val_loss: 0.4445
# Epoch 15/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7878 - loss: 5995.4307 - val_accuracy: 0.8083 - val_loss: 0.4466
# Epoch 16/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7890 - loss: 5905.4370 - val_accuracy: 0.7794 - val_loss: 0.4594
# Epoch 17/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7949 - loss: 5849.8052 - val_accuracy: 0.7269 - val_loss: 0.5189
# Epoch 18/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7961 - loss: 5770.0337 - val_accuracy: 0.7851 - val_loss: 0.4611
# Epoch 19/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7990 - loss: 5800.8486 - val_accuracy: 0.7494 - val_loss: 0.5071
# Epoch 20/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8014 - loss: 5704.3755 - val_accuracy: 0.7346 - val_loss: 0.5254
# Epoch 21/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7927 - loss: 5785.5737 - val_accuracy: 0.7151 - val_loss: 0.5713
# Epoch 22/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8029 - loss: 5646.4248 - val_accuracy: 0.7194 - val_loss: 0.5543
# Epoch 23/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7958 - loss: 5770.6147 - val_accuracy: 0.7911 - val_loss: 0.4418
# Epoch 24/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7991 - loss: 5741.1240 - val_accuracy: 0.7869 - val_loss: 0.4669
# Epoch 25/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8030 - loss: 5706.2329 - val_accuracy: 0.7720 - val_loss: 0.4759
# Epoch 26/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8004 - loss: 5690.8501 - val_accuracy: 0.7506 - val_loss: 0.4993
# Epoch 27/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7987 - loss: 5693.3101 - val_accuracy: 0.7863 - val_loss: 0.4566
# Epoch 28/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8012 - loss: 5598.1050 - val_accuracy: 0.7649 - val_loss: 0.4719
# Epoch 29/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8041 - loss: 5501.1929 - val_accuracy: 0.7371 - val_loss: 0.5073
# Epoch 30/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8072 - loss: 5503.5864 - val_accuracy: 0.7997 - val_loss: 0.4408
# Epoch 31/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8134 - loss: 5499.9536 - val_accuracy: 0.8089 - val_loss: 0.4251
# Epoch 32/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8109 - loss: 5451.8154 - val_accuracy: 0.7877 - val_loss: 0.4400
# Epoch 33/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8086 - loss: 5474.9546 - val_accuracy: 0.7983 - val_loss: 0.4314
# Epoch 34/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8108 - loss: 5516.1987 - val_accuracy: 0.7263 - val_loss: 0.5324
# Epoch 35/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8054 - loss: 5531.4258 - val_accuracy: 0.7660 - val_loss: 0.4885
# Epoch 36/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8079 - loss: 5538.2017 - val_accuracy: 0.7503 - val_loss: 0.5041
# Epoch 37/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8105 - loss: 5464.2896 - val_accuracy: 0.7840 - val_loss: 0.4562
# Epoch 38/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8125 - loss: 5361.5010 - val_accuracy: 0.8006 - val_loss: 0.4463
# Epoch 39/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8141 - loss: 5427.3760 - val_accuracy: 0.7346 - val_loss: 0.5178
# Epoch 40/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8123 - loss: 5333.6641 - val_accuracy: 0.8266 - val_loss: 0.4170
# Epoch 41/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8201 - loss: 5329.5293 - val_accuracy: 0.7663 - val_loss: 0.4916
# Epoch 42/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8199 - loss: 5264.2061 - val_accuracy: 0.8080 - val_loss: 0.4362
# Epoch 43/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8175 - loss: 5322.1294 - val_accuracy: 0.8109 - val_loss: 0.4377
# Epoch 44/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8146 - loss: 5364.8774 - val_accuracy: 0.7914 - val_loss: 0.4391
# Epoch 45/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8165 - loss: 5333.1797 - val_accuracy: 0.7609 - val_loss: 0.4884
# Epoch 46/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8111 - loss: 5339.9556 - val_accuracy: 0.7780 - val_loss: 0.4858
# Epoch 47/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8181 - loss: 5257.8057 - val_accuracy: 0.8017 - val_loss: 0.4515
# Epoch 48/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8213 - loss: 5229.0996 - val_accuracy: 0.7677 - val_loss: 0.4873
# Epoch 49/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8177 - loss: 5220.8311 - val_accuracy: 0.7940 - val_loss: 0.4580
# Epoch 50/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8252 - loss: 5150.1797 - val_accuracy: 0.7957 - val_loss: 0.4439
# Epoch 51/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8230 - loss: 5169.2671 - val_accuracy: 0.7860 - val_loss: 0.4612
# Epoch 52/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8193 - loss: 5185.4927 - val_accuracy: 0.8034 - val_loss: 0.4271
# Epoch 53/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8110 - loss: 5337.4888 - val_accuracy: 0.7817 - val_loss: 0.4588
# Epoch 54/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8197 - loss: 5200.5317 - val_accuracy: 0.7571 - val_loss: 0.4812
# Epoch 55/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8197 - loss: 5197.4238 - val_accuracy: 0.7366 - val_loss: 0.5100
# Epoch 56/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8169 - loss: 5137.2754 - val_accuracy: 0.7943 - val_loss: 0.4376
# Epoch 57/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8241 - loss: 5150.2153 - val_accuracy: 0.7611 - val_loss: 0.4877
# Epoch 58/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8158 - loss: 5239.5557 - val_accuracy: 0.7563 - val_loss: 0.4853
# Epoch 59/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8234 - loss: 5128.4985 - val_accuracy: 0.7571 - val_loss: 0.4804
# Epoch 60/100
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8158 - loss: 5201.8970 - val_accuracy: 0.8123 - val_loss: 0.4205
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 40.
# 量化 说话人识别模型
# INFO:tensorflow:Assets written to: /tmp/tmpwzqimz8w/assets
# INFO:tensorflow:Assets written to: /tmp/tmpwzqimz8w/assets
# Saved artifact at '/tmp/tmpwzqimz8w'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 31, 12, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   140540554073040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140540554073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140540554075728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140540554074576: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/lidonghaowsl/miniconda3/envs/vesc2025-algo/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1753280713.718596   79567 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753280713.718630   79567 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-23 22:25:13.719519: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpwzqimz8w
# 2025-07-23 22:25:13.720729: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-23 22:25:13.720751: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpwzqimz8w
# I0000 00:00:1753280713.736803   79567 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-07-23 22:25:13.738110: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-23 22:25:13.762308: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpwzqimz8w
# 2025-07-23 22:25:13.768280: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 48768 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# ✅ 两个模型已训练并量化完成！文件: spk-OFFICIAL_ALL-NO_NOISE_hid512_7X12_epoch100_2cls_seed58.tflite
