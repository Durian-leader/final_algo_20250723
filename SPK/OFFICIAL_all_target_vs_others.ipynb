# %%
import os
import random
import shutil
from pathlib import Path
import numpy as np
import torch
import torchaudio
import soundfile as sf
from multiprocessing import Pool, cpu_count
import multiprocessing as mp
from silero_vad import load_silero_vad
from IPython.display import Audio
from scipy.fft import rfft, fft

# %%
import numpy as np

def adjust_array_length(arr: np.ndarray, n: int) -> np.ndarray:
    """
    调整输入数组的长度为 n。
    - 若 arr 长度 >= n，则随机抽取 n 个元素（不放回）；
    - 若 arr 长度 < n，则补齐至 n，补充部分来自于 arr 的随机采样（放回）。

    参数:
        arr (np.ndarray): 输入的一维或二维数组（假设按第一个维度为样本维）。
        n (int): 目标长度。

    返回:
        np.ndarray: 调整后的数组，长度为 n。
    """
    arr_len = len(arr)
    if arr_len >= n:
        idx = np.random.choice(arr_len, n, replace=False)
        return arr[idx]
    else:
        deficit = n - arr_len
        idx = np.random.choice(arr_len, deficit, replace=True)
        extra_arr = arr[idx]
        return np.concatenate([arr, extra_arr], axis=0)

# %%
import numpy as np
from collections import Counter

# NOISE
X_NOISE = np.load('OFFICIAL/NOISE/03mfcc/X.npy')
Y_NOISE = np.load('OFFICIAL/NOISE/03mfcc/Y.npy')

# 打印样本数量
print(f'✅ X_NOISE 长度：{len(X_NOISE)}')
print(f'✅ Y_NOISE 长度：{len(Y_NOISE)}')

# 打印形状（假设是 numpy 数组）
print(f'📐 X_NOISE 形状: {X_NOISE.shape}')          # e.g. (13600, 8000)
print(f'📐 Y_NOISE 形状: {Y_NOISE.shape}')          # e.g. (13600,)

# 打印标签各类数量
label_counts = Counter(Y_NOISE)
print('📊 标签类别数量分布:')
for label, count in sorted(label_counts.items()):
    print(f'  类别 {label}: {count} 个样本')
# Out:
# ✅ X_NOISE 长度：7000
# ✅ Y_NOISE 长度：7000
# 📐 X_NOISE 形状: (7000, 8000)
# 📐 Y_NOISE 形状: (7000,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 1000 个样本
#   类别 2: 500 个样本
#   类别 3: 1000 个样本
#   类别 4: 1000 个样本
#   类别 5: 3000 个样本

# %%
import numpy as np
from collections import Counter
from pathlib import Path

categories = ['BOARD', 'IPAD', 'DIY', 'OTHERS', 'PC', 'PHONE']
base_path = Path('OFFICIAL')

# 数据字典：每类一个子字典，包含 X, X_mfcc, Y
data_dict = {}

for cat in categories:
    prefix = cat.upper()
    folder = base_path / prefix / '03mfcc'
    try:
        # 加载数据
        X = np.load(folder / 'X.npy')
        X_mfcc = np.load(folder / 'X_mfcc.npy')
        Y = np.load(folder / 'Y.npy')

        # 存入字典
        data_dict[prefix] = {
            'X': X,
            'X_mfcc': X_mfcc,
            'Y': Y
        }

        # 打印信息
        print(f'\n📁 加载类别：{prefix}')
        print(f'✅ X 长度：{len(X)}')
        print(f'✅ Y 长度：{len(Y)}')
        print(f'✅ X_mfcc 长度：{len(X_mfcc)}')
        print(f'📐 X 形状: {X.shape}')
        print(f'📐 X_mfcc 形状: {X_mfcc.shape}')
        print(f'📐 Y 形状: {Y.shape}')

        # 标签统计
        label_counts = Counter(Y)
        print('📊 标签类别数量分布:')
        for label, count in sorted(label_counts.items()):
            print(f'  类别 {label}: {count} 个样本')

    except FileNotFoundError as e:
        print(f'❌ 类别 {prefix} 加载失败: {e}')
# Out:
# 📁 加载类别：BOARD
# ✅ X 长度：14500
# ✅ Y 长度：14500
# ✅ X_mfcc 长度：14500
# 📐 X 形状: (14500, 8000)
# 📐 X_mfcc 形状: (14500, 31, 13)
# 📐 Y 形状: (14500,)
# 📊 标签类别数量分布:
#   类别 0: 2900 个样本
#   类别 1: 2900 个样本
#   类别 2: 2900 个样本
#   类别 3: 2900 个样本
#   类别 4: 2900 个样本
#
# 📁 加载类别：IPAD
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：DIY
# ✅ X 长度：9000
# ✅ Y 长度：9000
# ✅ X_mfcc 长度：9000
# 📐 X 形状: (9000, 8000)
# 📐 X_mfcc 形状: (9000, 31, 13)
# 📐 Y 形状: (9000,)
# 📊 标签类别数量分布:
#   类别 0: 1800 个样本
#   类别 1: 1800 个样本
#   类别 2: 1800 个样本
#   类别 3: 1800 个样本
#   类别 4: 1800 个样本
#
# 📁 加载类别：OTHERS
# ✅ X 长度：2770
# ✅ Y 长度：2770
# ✅ X_mfcc 长度：2770
# 📐 X 形状: (2770, 8000)
# 📐 X_mfcc 形状: (2770, 31, 13)
# 📐 Y 形状: (2770,)
# 📊 标签类别数量分布:
#   类别 4: 2770 个样本
#
# 📁 加载类别：PC
# ✅ X 长度：2500
# ✅ Y 长度：2500
# ✅ X_mfcc 长度：2500
# 📐 X 形状: (2500, 8000)
# 📐 X_mfcc 形状: (2500, 31, 13)
# 📐 Y 形状: (2500,)
# 📊 标签类别数量分布:
#   类别 0: 500 个样本
#   类别 1: 500 个样本
#   类别 2: 500 个样本
#   类别 3: 500 个样本
#   类别 4: 500 个样本
#
# 📁 加载类别：PHONE
# ✅ X 长度：15000
# ✅ Y 长度：15000
# ✅ X_mfcc 长度：15000
# 📐 X 形状: (15000, 8000)
# 📐 X_mfcc 形状: (15000, 31, 13)
# 📐 Y 形状: (15000,)
# 📊 标签类别数量分布:
#   类别 0: 3000 个样本
#   类别 1: 3000 个样本
#   类别 2: 3000 个样本
#   类别 3: 3000 个样本
#   类别 4: 3000 个样本

# %%
def sample_and_concat(data_dict, length_dict):
    """
    根据指定长度从 data_dict 中每个类别抽样（或补齐），返回拼接后的 X, X_mfcc, Y。

    参数:
        data_dict (dict): 类别 -> {'X': ..., 'X_mfcc': ..., 'Y': ...}
        length_dict (dict): 类别 -> 每类取样数（int）

    返回:
        X_all, X_mfcc_all, Y_all: 拼接后的 numpy 数组
    """
    X_list = []
    X_mfcc_list = []
    Y_list = []

    for cat, n in length_dict.items():
        if cat not in data_dict:
            print(f"⚠️ 类别 {cat} 不在 data_dict 中，跳过。")
            continue

        group = data_dict[cat]
        X = adjust_array_length(group['X'], n)
        X_mfcc = adjust_array_length(group['X_mfcc'], n)
        Y = adjust_array_length(group['Y'], n)

        X_list.append(X)
        X_mfcc_list.append(X_mfcc)
        Y_list.append(Y)

        print(f"✅ 类别 {cat}: 已采样 {n} 条")

    X_all = np.concatenate(X_list, axis=0)
    X_mfcc_all = np.concatenate(X_mfcc_list, axis=0)
    Y_all = np.concatenate(Y_list, axis=0)

    print(f"🎯 合并后总样本数: {len(Y_all)}")
    return X_all, X_mfcc_all, Y_all

# %%
length_dict = {
    'BOARD': 15000,
    'PHONE': 3000,
    'IPAD': 3000,
    'PC': 3000,
    'OTHERS': 2000,
    'DIY': 9000
}

X, X_mfcc, Y = sample_and_concat(data_dict, length_dict)
# Out:
# ✅ 类别 BOARD: 已采样 15000 条
# ✅ 类别 PHONE: 已采样 3000 条
# ✅ 类别 IPAD: 已采样 3000 条
# ✅ 类别 PC: 已采样 3000 条
# ✅ 类别 OTHERS: 已采样 2000 条
# ✅ 类别 DIY: 已采样 9000 条
# 🎯 合并后总样本数: 35000

# %%
output_dir = Path("OFFICIAL_ALL/NO_NOISE")
output_dir.mkdir(parents=True, exist_ok=True)

np.save(output_dir / "X.npy", X)
np.save(output_dir / "X_mfcc.npy", X_mfcc)
np.save(output_dir / "Y.npy", Y)

# %% [markdown]
# ## 加噪声

# %%
def mix_audio_batches(signal_batch, noise_batch, snr_list, normalize_audio_batch):
    """
    从 signal_batch (n, 8000) 和 noise_batch (m, 8000) 中随机混音，按 snr_list 中的 SNR 进行混音，直至 signal_batch 抽完。
    返回: 一个字典，键为 SNR，值为对应混音后的 numpy 数组 (n, 8000)。
    """
    n, _ = signal_batch.shape
    m, _ = noise_batch.shape

    # 随机顺序抽取 signal_batch（不放回）
    signal_indices = np.random.permutation(n)

    # 为每个 SNR 创建空列表
    mixed_audio_dict = {snr: [] for snr in snr_list}

    for idx in signal_indices:
        # 当前信号
        signal = signal_batch[idx]

        # 随机从 noise_batch（有放回）抽一个
        noise_idx = np.random.randint(0, m)
        noise = noise_batch[noise_idx]

        # 计算信号和噪声功率
        signal_power = np.mean(signal ** 2)
        noise_power = np.mean(noise ** 2)

        # 避免除0
        if noise_power == 0:
            noise_power = 1e-12

        for snr in snr_list:
            # 计算缩放因子
            target_noise_power = signal_power / (10 ** (snr / 10))
            scaling_factor = np.sqrt(target_noise_power / noise_power)

            # 混音
            mixed = signal + scaling_factor * noise
            mixed_audio_dict[snr].append(mixed)

    # 转换为 numpy 数组并进行归一化
    for snr in snr_list:
        mixed_audio = np.stack(mixed_audio_dict[snr], axis=0)
        mixed_audio = normalize_audio_batch(mixed_audio)
        mixed_audio_dict[snr] = mixed_audio

    return mixed_audio_dict


def concatenate_mixed_audio(mixed_audio_dict: dict) -> np.ndarray:
    """
    将混音字典中的所有 SNR 的 numpy 数组拼接为一个大的 numpy 数组。
    
    参数:
    mixed_audio_dict: dict，键是 SNR，值是 (n, 8000) 的 numpy 数组。
    
    返回:
    拼接后的 numpy 数组，形状是 (sum_n, 8000)。
    """
    # 取出所有值（每个 numpy 数组）并拼接
    concatenated = np.concatenate(list(mixed_audio_dict.values()), axis=0)
    return concatenated

# %%
# 混音
snr_list = [-3,0,10,100]
mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 混音
#       2 snr_list = [-3,0,10,100]
# ----> 3 mixed_audio_dict = mix_audio_batches(X, X_NOISE, snr_list, normalize_audio_batch)
#       4 mixed_audio_numpy = concatenate_mixed_audio(mixed_audio_dict)
#
# NameError: name 'normalize_audio_batch' is not defined

# %% [markdown]
# # 训练

# %%
root_dir = Path(f'OFFICIAL_ALL/NO_NOISE')

X = np.load(root_dir / "X.npy")
Y = np.load(root_dir / "Y.npy")
X_mfcc = np.load(root_dir / "X_mfcc.npy")

# 打印加载后的数据形状
print("加载后的 X 形状:", X.shape)  
print("加载后的 Y 形状:", Y.shape)
print("加载后的 X_mfcc 形状:", X_mfcc.shape)

# 打印标签  
unique_labels, counts = np.unique(Y, return_counts=True)
label_distribution = dict(zip(unique_labels, counts))
print("标签分布:", label_distribution)
# Out:
# 加载后的 X 形状: (35000, 8000)
# 加载后的 Y 形状: (35000,)
# 加载后的 X_mfcc 形状: (35000, 31, 13)
# 标签分布: {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}

# %%
# 标签重新映射：将0-3的标签都设为0，4的类别设为1
Y_binary = np.where(Y == 4, 1, 0)

# 验证映射结果
print("重新映射前的标签分布:")
unique_labels_old, counts_old = np.unique(Y, return_counts=True)
label_distribution_old = dict(zip(unique_labels_old, counts_old))
print(label_distribution_old)

print("\n重新映射后的标签分布:")
unique_labels_new, counts_new = np.unique(Y_binary, return_counts=True)
label_distribution_new = dict(zip(unique_labels_new, counts_new))
print(label_distribution_new)

# 验证映射是否正确
print(f"\n原来类别0-3的总数: {6591 + 6577 + 6646 + 6602} = {sum([6591, 6577, 6646, 6602])}")
print(f"原来类别4的总数: {8584}")
print(f"新标签0的数量: {label_distribution_new[0]}")
print(f"新标签1的数量: {label_distribution_new[1]}")

# 更新Y为新的二分类标签
Y = Y_binary

print(f"\n最终的Y形状: {Y.shape}")
print(f"最终的标签分布: {dict(zip(*np.unique(Y, return_counts=True)))}")
# Out:
# 重新映射前的标签分布:
# {np.int32(0): np.int64(6591), np.int32(1): np.int64(6577), np.int32(2): np.int64(6646), np.int32(3): np.int64(6602), np.int32(4): np.int64(8584)}
#
# 重新映射后的标签分布:
# {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}
#
# 原来类别0-3的总数: 26416 = 26416
# 原来类别4的总数: 8584
# 新标签0的数量: 26416
# 新标签1的数量: 8584
#
# 最终的Y形状: (35000,)
# 最终的标签分布: {np.int64(0): np.int64(26416), np.int64(1): np.int64(8584)}

# %%
print("去掉第一维前形状:", X_mfcc.shape)
X_mfcc_no_first = X_mfcc[:, :, 1:]
print("去掉第一维后形状:", X_mfcc_no_first.shape)
X_mfcc_no_first = X_mfcc_no_first.reshape(X_mfcc_no_first.shape[0], 31, 12, 1)  
print("X_mfcc 形状:", X_mfcc_no_first.shape)
# Out:
# 去掉第一维前形状: (35000, 31, 13)
# 去掉第一维后形状: (35000, 31, 12)
# X_mfcc 形状: (35000, 31, 12, 1)

# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
def create_speaker_model():
    # 定义输入
    inputs = tf.keras.Input(shape=(31, 12, 1))
    
    # 逐层传递x
    # 第一步：Conv2D卷积操作（不包含激活函数）
    x = tf.keras.layers.Conv2D(256, kernel_size=(9, 12), padding='valid')(inputs)
    # 第二步：单独应用ReLU激活函数
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(23, 1), padding='valid')(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(2, activation='softmax')(x)
    
    # 创建模型
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model
# 量化转换函数
def quantize_model(model, X_sample):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type = tf.int8
    converter.inference_output_type = tf.int8

    def representative_dataset():
        for i in range(min(100, len(X_sample))):
            data = X_sample[i:i+1]
            yield [tf.cast(data, tf.float32)]
    
    converter.representative_dataset = representative_dataset
    tflite_quant_model = converter.convert()
    return tflite_quant_model


# 数据划分
spk_X_train, spk_X_val, spk_Y_train, spk_Y_val = train_test_split(X_mfcc_no_first, Y, test_size=0.1, random_state=58) #42

# 标签 one-hot

spk_Y_train_cat = tf.keras.utils.to_categorical(spk_Y_train, num_classes=2)
spk_Y_val_cat = tf.keras.utils.to_categorical(spk_Y_val, num_classes=2)

# 创建模型
spk_model = create_speaker_model()

# 编译
spk_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 训练
print("\n开始训练 说话人识别模型")
class_weight = {0: 8584, 1: 26416}  
from tensorflow.keras.callbacks import EarlyStopping
# 配置 EarlyStopping 回调
earlystop = EarlyStopping(
    monitor='val_accuracy',       # 监控的指标，常用 'val_loss' 或 'val_accuracy'
    patience=100,               # 容忍多少个 epoch 没有提升
    restore_best_weights=True, # 回到验证集表现最好的模型
    verbose=1                 # 显示早停信息
)
spk_history = spk_model.fit(
    spk_X_train, spk_Y_train_cat,
    validation_data=(spk_X_val, spk_Y_val_cat),
    epochs=1000,
    batch_size=32,
    callbacks=[earlystop],     # 添加回调函数
    class_weight=class_weight
)

# 量化转换
print("量化 说话人识别模型")
spk_quant_tflite = quantize_model(spk_model, spk_X_train[:10000])  # 添加一个维度以匹配输入形状 (n, 31, 13, 1)
file_path = "spk-OFFICIAL_ALL-NO_NOISE_hid512_9X12_epoch500_2cls_seed58_val_accuracy.tflite"
with open(file_path, "wb") as f:
    f.write(spk_quant_tflite)

print(f"\n✅ 两个模型已训练并量化完成！文件: {file_path}")
# Out:
# 2025-07-24 08:29:28.724740: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-24 08:29:28.910171: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753316968.984173   27692 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753316969.005662   27692 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753316969.160309   27692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753316969.160331   27692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753316969.160333   27692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753316969.160334   27692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-24 08:29:29.182636: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1753316974.477793   27692 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45763 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:73:00.0, compute capability: 8.6
# 开始训练 说话人识别模型
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753316977.783804   28068 service.cc:152] XLA service 0x7f9348002730 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753316977.783848   28068 service.cc:160]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-07-24 08:29:37.847633: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753316977.984558   28068 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  38/985 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5190 - loss: 9309.5381
# I0000 00:00:1753316981.037434   28068 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.6444 - loss: 8062.9160 - val_accuracy: 0.6723 - val_loss: 0.5951
# Epoch 2/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7148 - loss: 7209.7075 - val_accuracy: 0.7514 - val_loss: 0.5180
# Epoch 3/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7462 - loss: 6796.2153 - val_accuracy: 0.7331 - val_loss: 0.5348
# Epoch 4/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7537 - loss: 6587.5254 - val_accuracy: 0.6920 - val_loss: 0.5708
# Epoch 5/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7704 - loss: 6360.1392 - val_accuracy: 0.7720 - val_loss: 0.4768
# Epoch 6/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7705 - loss: 6244.4878 - val_accuracy: 0.7674 - val_loss: 0.4653
# Epoch 7/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7842 - loss: 6076.5864 - val_accuracy: 0.7671 - val_loss: 0.4773
# Epoch 8/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7886 - loss: 5968.4902 - val_accuracy: 0.7886 - val_loss: 0.4563
# Epoch 9/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7957 - loss: 5805.4551 - val_accuracy: 0.7509 - val_loss: 0.5111
# Epoch 10/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.7919 - loss: 5771.6353 - val_accuracy: 0.7580 - val_loss: 0.4821
# Epoch 11/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8075 - loss: 5574.7373 - val_accuracy: 0.7346 - val_loss: 0.5136
# Epoch 12/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8069 - loss: 5553.8467 - val_accuracy: 0.7811 - val_loss: 0.4548
# Epoch 13/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8101 - loss: 5430.7500 - val_accuracy: 0.7929 - val_loss: 0.4406
# Epoch 14/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8114 - loss: 5425.6938 - val_accuracy: 0.7983 - val_loss: 0.4456
# Epoch 15/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8150 - loss: 5365.0527 - val_accuracy: 0.7769 - val_loss: 0.4675
# Epoch 16/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8139 - loss: 5298.9375 - val_accuracy: 0.8077 - val_loss: 0.4268
# Epoch 17/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8201 - loss: 5261.1445 - val_accuracy: 0.7791 - val_loss: 0.4841
# Epoch 18/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8316 - loss: 4984.0913 - val_accuracy: 0.7131 - val_loss: 0.5549
# Epoch 19/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8264 - loss: 5021.1768 - val_accuracy: 0.8071 - val_loss: 0.4385
# Epoch 20/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8377 - loss: 4931.2734 - val_accuracy: 0.8086 - val_loss: 0.4371
# Epoch 21/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8309 - loss: 4945.4536 - val_accuracy: 0.7743 - val_loss: 0.4502
# Epoch 22/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8338 - loss: 4775.1558 - val_accuracy: 0.7123 - val_loss: 0.5634
# Epoch 23/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8284 - loss: 4867.7910 - val_accuracy: 0.7763 - val_loss: 0.4627
# Epoch 24/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8368 - loss: 4709.2104 - val_accuracy: 0.7714 - val_loss: 0.4764
# Epoch 25/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8381 - loss: 4730.2954 - val_accuracy: 0.7423 - val_loss: 0.5111
# Epoch 26/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8408 - loss: 4638.1860 - val_accuracy: 0.8057 - val_loss: 0.4305
# Epoch 27/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8463 - loss: 4503.1567 - val_accuracy: 0.7751 - val_loss: 0.4644
# Epoch 28/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8508 - loss: 4454.4043 - val_accuracy: 0.7709 - val_loss: 0.5064
# Epoch 29/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8482 - loss: 4501.8262 - val_accuracy: 0.7631 - val_loss: 0.4829
# Epoch 30/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8457 - loss: 4475.3789 - val_accuracy: 0.8006 - val_loss: 0.4458
# Epoch 31/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8482 - loss: 4474.1167 - val_accuracy: 0.7706 - val_loss: 0.4830
# Epoch 32/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8519 - loss: 4301.2842 - val_accuracy: 0.7711 - val_loss: 0.4839
# Epoch 33/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8558 - loss: 4288.9634 - val_accuracy: 0.7851 - val_loss: 0.4568
# Epoch 34/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8544 - loss: 4218.8667 - val_accuracy: 0.7951 - val_loss: 0.4454
# Epoch 35/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8595 - loss: 4199.7485 - val_accuracy: 0.7937 - val_loss: 0.4600
# Epoch 36/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8562 - loss: 4247.1953 - val_accuracy: 0.8117 - val_loss: 0.4361
# Epoch 37/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8583 - loss: 4150.5449 - val_accuracy: 0.7929 - val_loss: 0.4578
# Epoch 38/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8594 - loss: 4138.8569 - val_accuracy: 0.7654 - val_loss: 0.5197
# Epoch 39/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8552 - loss: 4110.8818 - val_accuracy: 0.7897 - val_loss: 0.4556
# Epoch 40/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8654 - loss: 3982.8293 - val_accuracy: 0.7566 - val_loss: 0.5095
# Epoch 41/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8595 - loss: 4012.7979 - val_accuracy: 0.7466 - val_loss: 0.5353
# Epoch 42/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8575 - loss: 4057.3127 - val_accuracy: 0.8114 - val_loss: 0.4797
# Epoch 43/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8613 - loss: 4066.2041 - val_accuracy: 0.7586 - val_loss: 0.5175
# Epoch 44/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8612 - loss: 3935.2537 - val_accuracy: 0.8237 - val_loss: 0.4500
# Epoch 45/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8661 - loss: 3930.2896 - val_accuracy: 0.7954 - val_loss: 0.4889
# Epoch 46/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8712 - loss: 3803.9324 - val_accuracy: 0.8131 - val_loss: 0.4701
# Epoch 47/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8704 - loss: 3766.4990 - val_accuracy: 0.7734 - val_loss: 0.4918
# Epoch 48/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8726 - loss: 3770.1172 - val_accuracy: 0.7843 - val_loss: 0.4860
# Epoch 49/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8705 - loss: 3788.3521 - val_accuracy: 0.7809 - val_loss: 0.4878
# Epoch 50/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8737 - loss: 3671.5483 - val_accuracy: 0.7766 - val_loss: 0.5016
# Epoch 51/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8758 - loss: 3596.1426 - val_accuracy: 0.7520 - val_loss: 0.5419
# Epoch 52/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8742 - loss: 3605.2700 - val_accuracy: 0.7794 - val_loss: 0.5195
# Epoch 53/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8736 - loss: 3584.7532 - val_accuracy: 0.7817 - val_loss: 0.5067
# Epoch 54/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8793 - loss: 3524.5232 - val_accuracy: 0.7720 - val_loss: 0.5197
# Epoch 55/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8771 - loss: 3586.4822 - val_accuracy: 0.7591 - val_loss: 0.5441
# Epoch 56/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8765 - loss: 3574.2737 - val_accuracy: 0.7663 - val_loss: 0.5256
# Epoch 57/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8788 - loss: 3558.2642 - val_accuracy: 0.7680 - val_loss: 0.5226
# Epoch 58/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8782 - loss: 3557.6208 - val_accuracy: 0.7923 - val_loss: 0.5193
# Epoch 59/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8863 - loss: 3434.4395 - val_accuracy: 0.7771 - val_loss: 0.5294
# Epoch 60/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8826 - loss: 3418.7476 - val_accuracy: 0.7583 - val_loss: 0.5693
# Epoch 61/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8844 - loss: 3416.2124 - val_accuracy: 0.7531 - val_loss: 0.5715
# Epoch 62/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8832 - loss: 3399.1399 - val_accuracy: 0.7863 - val_loss: 0.5338
# Epoch 63/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8848 - loss: 3395.8135 - val_accuracy: 0.7603 - val_loss: 0.5521
# Epoch 64/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8846 - loss: 3359.5391 - val_accuracy: 0.7174 - val_loss: 0.6986
# Epoch 65/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8869 - loss: 3383.6638 - val_accuracy: 0.7523 - val_loss: 0.5625
# Epoch 66/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8848 - loss: 3353.1311 - val_accuracy: 0.7760 - val_loss: 0.5242
# Epoch 67/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8881 - loss: 3267.0376 - val_accuracy: 0.7471 - val_loss: 0.5921
# Epoch 68/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8897 - loss: 3280.6909 - val_accuracy: 0.7766 - val_loss: 0.5575
# Epoch 69/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8879 - loss: 3310.8833 - val_accuracy: 0.7906 - val_loss: 0.5200
# Epoch 70/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8893 - loss: 3235.1567 - val_accuracy: 0.7931 - val_loss: 0.5074
# Epoch 71/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8884 - loss: 3303.5027 - val_accuracy: 0.7489 - val_loss: 0.5900
# Epoch 72/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8895 - loss: 3241.5007 - val_accuracy: 0.7791 - val_loss: 0.5401
# Epoch 73/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8924 - loss: 3187.5701 - val_accuracy: 0.7906 - val_loss: 0.5513
# Epoch 74/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8946 - loss: 3126.7441 - val_accuracy: 0.7800 - val_loss: 0.5482
# Epoch 75/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8949 - loss: 3104.7798 - val_accuracy: 0.7366 - val_loss: 0.6389
# Epoch 76/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8844 - loss: 3297.0833 - val_accuracy: 0.7800 - val_loss: 0.5625
# Epoch 77/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8897 - loss: 3231.8503 - val_accuracy: 0.7874 - val_loss: 0.5568
# Epoch 78/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8920 - loss: 3074.6973 - val_accuracy: 0.7809 - val_loss: 0.5512
# Epoch 79/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8942 - loss: 3076.9211 - val_accuracy: 0.7614 - val_loss: 0.5849
# Epoch 80/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8933 - loss: 3130.7810 - val_accuracy: 0.7680 - val_loss: 0.5942
# Epoch 81/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8919 - loss: 3095.3477 - val_accuracy: 0.8057 - val_loss: 0.5484
# Epoch 82/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8983 - loss: 3021.5413 - val_accuracy: 0.8109 - val_loss: 0.5381
# Epoch 83/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8975 - loss: 3079.4224 - val_accuracy: 0.7663 - val_loss: 0.5793
# Epoch 84/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8954 - loss: 3035.3064 - val_accuracy: 0.7817 - val_loss: 0.5588
# Epoch 85/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8965 - loss: 2993.0012 - val_accuracy: 0.8129 - val_loss: 0.5647
# Epoch 86/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8947 - loss: 3140.2463 - val_accuracy: 0.7740 - val_loss: 0.5914
# Epoch 87/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9011 - loss: 2923.2053 - val_accuracy: 0.7629 - val_loss: 0.6125
# Epoch 88/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8977 - loss: 2925.5664 - val_accuracy: 0.7606 - val_loss: 0.6381
# Epoch 89/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8954 - loss: 3028.3735 - val_accuracy: 0.7957 - val_loss: 0.5823
# Epoch 90/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8965 - loss: 3027.7173 - val_accuracy: 0.7629 - val_loss: 0.6018
# Epoch 91/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8948 - loss: 3022.0569 - val_accuracy: 0.7903 - val_loss: 0.5631
# Epoch 92/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9005 - loss: 2983.2720 - val_accuracy: 0.7940 - val_loss: 0.5874
# Epoch 93/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9000 - loss: 2923.0781 - val_accuracy: 0.7769 - val_loss: 0.5903
# Epoch 94/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9033 - loss: 2904.8430 - val_accuracy: 0.7631 - val_loss: 0.6237
# Epoch 95/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9048 - loss: 2838.4688 - val_accuracy: 0.7800 - val_loss: 0.5893
# Epoch 96/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8939 - loss: 2976.4229 - val_accuracy: 0.7626 - val_loss: 0.6348
# Epoch 97/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9032 - loss: 2821.9900 - val_accuracy: 0.7734 - val_loss: 0.5960
# Epoch 98/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8989 - loss: 2955.0137 - val_accuracy: 0.7737 - val_loss: 0.5960
# Epoch 99/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9040 - loss: 2856.9224 - val_accuracy: 0.7840 - val_loss: 0.6070
# Epoch 100/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9069 - loss: 2766.5176 - val_accuracy: 0.7694 - val_loss: 0.6158
# Epoch 101/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9013 - loss: 2822.5581 - val_accuracy: 0.7866 - val_loss: 0.5835
# Epoch 102/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9035 - loss: 2805.7529 - val_accuracy: 0.7571 - val_loss: 0.6401
# Epoch 103/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9055 - loss: 2846.1592 - val_accuracy: 0.7980 - val_loss: 0.5827
# Epoch 104/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9010 - loss: 2824.6372 - val_accuracy: 0.8166 - val_loss: 0.5749
# Epoch 105/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9080 - loss: 2770.3193 - val_accuracy: 0.7911 - val_loss: 0.6238
# Epoch 106/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9060 - loss: 2754.4561 - val_accuracy: 0.7597 - val_loss: 0.6717
# Epoch 107/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9059 - loss: 2819.1243 - val_accuracy: 0.7726 - val_loss: 0.6305
# Epoch 108/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9052 - loss: 2733.1616 - val_accuracy: 0.7789 - val_loss: 0.6427
# Epoch 109/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9033 - loss: 2804.3049 - val_accuracy: 0.7840 - val_loss: 0.6215
# Epoch 110/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9050 - loss: 2790.4590 - val_accuracy: 0.7726 - val_loss: 0.6242
# Epoch 111/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9030 - loss: 2840.5449 - val_accuracy: 0.7903 - val_loss: 0.6063
# Epoch 112/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9091 - loss: 2712.9382 - val_accuracy: 0.7809 - val_loss: 0.6434
# Epoch 113/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9029 - loss: 2844.1970 - val_accuracy: 0.7780 - val_loss: 0.6345
# Epoch 114/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9050 - loss: 2740.2598 - val_accuracy: 0.7811 - val_loss: 0.6226
# Epoch 115/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9064 - loss: 2701.4561 - val_accuracy: 0.8051 - val_loss: 0.6021
# Epoch 116/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9048 - loss: 2781.1187 - val_accuracy: 0.7454 - val_loss: 0.6918
# Epoch 117/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9087 - loss: 2664.4436 - val_accuracy: 0.7614 - val_loss: 0.6768
# Epoch 118/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9041 - loss: 2735.1877 - val_accuracy: 0.7651 - val_loss: 0.6531
# Epoch 119/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9079 - loss: 2763.3613 - val_accuracy: 0.7831 - val_loss: 0.6233
# Epoch 120/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9080 - loss: 2705.8965 - val_accuracy: 0.8160 - val_loss: 0.6316
# Epoch 121/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9086 - loss: 2633.1968 - val_accuracy: 0.8200 - val_loss: 0.6362
# Epoch 122/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9062 - loss: 2822.6782 - val_accuracy: 0.7880 - val_loss: 0.6452
# Epoch 123/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9090 - loss: 2621.8425 - val_accuracy: 0.7866 - val_loss: 0.6393
# Epoch 124/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9086 - loss: 2654.0291 - val_accuracy: 0.7991 - val_loss: 0.6526
# Epoch 125/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9059 - loss: 2739.5466 - val_accuracy: 0.7651 - val_loss: 0.6715
# Epoch 126/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9106 - loss: 2670.8013 - val_accuracy: 0.7951 - val_loss: 0.6443
# Epoch 127/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9089 - loss: 2680.9539 - val_accuracy: 0.7900 - val_loss: 0.6625
# Epoch 128/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9077 - loss: 2689.3381 - val_accuracy: 0.7891 - val_loss: 0.6374
# Epoch 129/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9069 - loss: 2655.3467 - val_accuracy: 0.7869 - val_loss: 0.6437
# Epoch 130/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9007 - loss: 2846.1992 - val_accuracy: 0.7791 - val_loss: 0.6545
# Epoch 131/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9106 - loss: 2603.2456 - val_accuracy: 0.7814 - val_loss: 0.6669
# Epoch 132/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9074 - loss: 2638.4275 - val_accuracy: 0.7940 - val_loss: 0.6410
# Epoch 133/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9070 - loss: 2740.6418 - val_accuracy: 0.7820 - val_loss: 0.6376
# Epoch 134/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9124 - loss: 2588.1543 - val_accuracy: 0.7820 - val_loss: 0.6675
# Epoch 135/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9100 - loss: 2595.0781 - val_accuracy: 0.7869 - val_loss: 0.6751
# Epoch 136/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9104 - loss: 2638.7195 - val_accuracy: 0.7531 - val_loss: 0.7910
# Epoch 137/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9091 - loss: 2632.7573 - val_accuracy: 0.7606 - val_loss: 0.7363
# Epoch 138/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9099 - loss: 2666.5222 - val_accuracy: 0.8034 - val_loss: 0.6775
# Epoch 139/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9080 - loss: 2618.8269 - val_accuracy: 0.7763 - val_loss: 0.6966
# Epoch 140/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9111 - loss: 2577.8511 - val_accuracy: 0.7917 - val_loss: 0.6610
# Epoch 141/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9092 - loss: 2678.0732 - val_accuracy: 0.7771 - val_loss: 0.6606
# Epoch 142/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9084 - loss: 2578.4233 - val_accuracy: 0.7803 - val_loss: 0.6731
# Epoch 143/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9113 - loss: 2578.4387 - val_accuracy: 0.7931 - val_loss: 0.6502
# Epoch 144/1000
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9092 - loss: 2614.4531 - val_accuracy: 0.7871 - val_loss: 0.6767
# Epoch 144: early stopping
# Restoring model weights from the end of the best epoch: 44.
# 量化 说话人识别模型
# INFO:tensorflow:Assets written to: /tmp/tmpy59_lpdf/assets
# INFO:tensorflow:Assets written to: /tmp/tmpy59_lpdf/assets
# Saved artifact at '/tmp/tmpy59_lpdf'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 31, 12, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   140286383910224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140286383909840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140286383912912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140286383911760: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/lidonghaowsl/miniconda3/envs/vesc2025-algo/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1753318006.134088   27692 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753318006.134105   27692 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-24 08:46:46.134604: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpy59_lpdf
# 2025-07-24 08:46:46.134987: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-24 08:46:46.134994: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpy59_lpdf
# I0000 00:00:1753318006.145758   27692 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-07-24 08:46:46.146256: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-24 08:46:46.168557: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpy59_lpdf
# 2025-07-24 08:46:46.174497: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 39895 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# ✅ 两个模型已训练并量化完成！文件: spk-OFFICIAL_ALL-NO_NOISE_hid512_9X12_epoch500_2cls_seed58_val_accuracy.tflite
